# %%
# %pip install xarray
# %pip install netCDF4
# %pip install mutagen
# %pip install cartopy
# %pip install moviepy
# %pip install moviepy editor
# !conda install -c conda-forge ffmpeg -y
# !pip install imgkit
# !conda install -c conda-forge manim --yes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 60.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 56.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 92.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [netCDF4]m1/2 [netCDF4]
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 110.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 111.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 97.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [cartopy]m3/4 [cartopy]
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.5/29.5 MB 106.0 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from main import Main
app = Main()
app.run()
# Out:
# Working directory: /home/ec2-user/SageMaker/v5_file_management
# Python path: ['/home/ec2-user/SageMaker/v5_file_management', '/home/ec2-user/anaconda3/envs/python3/lib/python310.zip', '/home/ec2-user/anaconda3/envs/python3/lib/python3.10', '/home/ec2-user/anaconda3/envs/python3/lib/python3.10/lib-dynload', '', '/home/ec2-user/.local/lib/python3.10/site-packages', '/home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages']
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from main import Main
#       2 app = Main()
#       3 app.run()
#
# File ~/SageMaker/v5_file_management/main.py:14
#      10     sys.path.insert(0, current_dir)
#      13 #\from code.data_cleaning import data_cleaning, daily_sub_dataset_creation, save_video_files_paths_in_json
# ---> 14 from code.video_concat import create_final_video
# ...

# %%
# !touch code/__init__.py
